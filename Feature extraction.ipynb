# %%
#trying to extract feature from the image

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from skimage.io import imread, imshow

image = imread('1.jpg', as_gray=True)
imshow(image)

# %%
image.shape
image
# Out:
# array([[0.00613098, 0.00613098, 0.00613098, ..., 0.02155725, 0.01763569,
#         0.01763569],
#        [0.00613098, 0.00613098, 0.00613098, ..., 0.01371412, 0.01371412,
#         0.02155725],
#        [0.00613098, 0.00613098, 0.00613098, ..., 0.00979255, 0.02155725,
#         0.02940039],
#        ...,
#        [0.15547098, 0.15547098, 0.16331412, ..., 0.16078431, 0.16078431,
#         0.1372549 ],
#        [0.15939255, 0.15939255, 0.16723569, ..., 0.19943451, 0.2745098 ,
#         0.19159137],
#        [0.1591098 , 0.1591098 , 0.16303137, ..., 0.21343922, 0.23472863,
#         0.21736078]])

# %%
# the above codes are image metrics example which was told in 3rd year
#Reminder always check the shape of the image before rescaling

# %%
image.shape
# Out:
# (417, 600)

# %%
feature=np.reshape(image,(417*600))
feature
# Out:
# array([0.00613098, 0.00613098, 0.00613098, ..., 0.21343922, 0.23472863,
#        0.21736078])

# %%
image=imread('testimage.jpg')
image
# Out:
# array([[[ 49,  35,  24],
#         [ 52,  36,  23],
#         [ 56,  36,  25],
#         ...,
#         [168, 202, 214],
#         [166, 200, 212],
#         [165, 198, 213]],
#
#        [[ 46,  34,  22],
#         [ 50,  33,  23],
#         [ 52,  34,  22],
#         ...,
#         [168, 202, 214],
#         [166, 200, 212],
#         [165, 199, 211]],
#
#        [[ 49,  37,  25],
#         [ 51,  37,  26],
#         [ 53,  37,  24],
#         ...,
#         [166, 202, 214],
#         [166, 202, 214],
#         [164, 200, 212]],
#
#        ...,
#
#        [[ 76,  57,  43],
#         [ 74,  57,  41],
#         [ 78,  61,  45],
#         ...,
#         [205, 215, 217],
#         [205, 215, 217],
#         [205, 215, 217]],
#
#        [[ 78,  59,  44],
#         [ 75,  58,  42],
#         [ 79,  62,  46],
#         ...,
#         [204, 214, 216],
#         [204, 214, 216],
#         [204, 214, 216]],
#
#        [[ 80,  61,  46],
#         [ 77,  60,  44],
#         [ 80,  63,  47],
# ...

# %%
image.shape
# Out:
# (339, 509, 3)

# %%
feature=np.reshape(image,(339*509*3))
feature
# Out:
# array([ 49,  35,  24, ..., 204, 214, 216], dtype=uint8)
